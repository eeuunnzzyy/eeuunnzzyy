# %% [markdown]
# # 네이버애견카페 - 숙소키워드 크롤링

# %% [markdown]
# ## 환경세팅

# %%
#분석 환경 세팅
from bs4 import BeautifulSoup
import urllib.request
import re
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.keys import Keys
import requests
from selenium.webdriver import ActionChains
import time

# %% [markdown]
# 저 위에거 없는거 다 다운 플리즈
# webdriver 인터넷에 검색해서 자기 구글크롬캐스트랑 제일 잘맞는거 선택
# 저는 참고로 걍 최신꺼했어여..

# %%
driver = webdriver.Chrome(executable_path='/Users/jeon-eunji/Documents/GitHub/TIL/크롤링/chromedriver')
# Out:
# /var/folders/3q/y966c1fj3lndmps8kk3plpy40000gn/T/ipykernel_9986/161936369.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='/Users/jeon-eunji/Documents/GitHub/TIL/크롤링/chromedriver')

# %%
#분석 진행상황 확인 및 경고창 무시하기
from tqdm import tqdm_notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 분석하기 1
# ## url 가져오기

# %% [markdown]
# driver로 들어간 빈페이지에서 m.naver.com 입력한다음 로그인 진행하고 하는걸 추천한다.
# 수작업이 들어가지만 덜복잡하다.

# %%
driver.get('https://m.cafe.naver.com/ca-fe/web/cafes/10258021/search?q=%EC%88%99%EC%86%8C&mi=0&ta=ARTICLE_COMMENT&pc=ALL&od=NEW')
for i in range(0,5):
    driver.find_element_by_tag_name('body').send_keys(Keys.PAGE_DOWN)
    time.sleep(1)

# %% [markdown]
# 해놓고 끝까지 내려갈때까지, 멈출때까지 기다려본다.

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup
# Out:
# <html lang="ko"><head><script src="https://openmain.pstatic.net/js/openmainBtn.js?2760667"></script><script defer="" src="https://ssl.pstatic.net/tveta/libs/ssp/ssp.web.sdk.js" type="text/javascript"></script><link href="https://ca-fe.pstatic.net/web-mobile/static/media-viewer/mobile-media-viewer.css" rel="stylesheet"/><title> 강사모 : 네이버 카페</title><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no,target-densitydpi=medium-dpi,viewport-fit=cover" name="viewport"/><meta content="noindex, nofollow" name="robots"/><meta content="always" name="referrer"/><link href="https://ca-fe.pstatic.net/web-mobile/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://cafe.pstatic.net/mobile/img/favicon2016/iOS7_120X120_iphone.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="https://cafe.pstatic.net/mobile/img/favicon2016/iOS7_152X152_ipad_retina.png" rel="apple-touch-icon-precomposed" sizes="
# ...

# %%
all_title = soup.select('div.article_box > strong.title')
len(all_title)
# Out:
# 60

# %%
soup1 = []
soup2 = []
soup3 = []
soup4 = []
title_txt = []
title_t = []
driver.get('https://m.cafe.naver.com/ca-fe/web/cafes/10258021/search?q=%EC%88%99%EC%86%8C&mi=0&ta=ARTICLE_COMMENT&pc=ALL&od=NEW')
for i in range(0,10):
    driver.find_element_by_tag_name('body').send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    soup1 = BeautifulSoup(driver.page_source, 'html.parser')
    all_title = soup1.select('div.article_box > strong.title')
    for x in range(len(all_title)):
        val = all_title[x].get_text("", strip=True)
        title_txt.append(val)
    val2 = title_txt
    title_t.append(val2)
title_t
# Out:
# [['울강아지 여신 원피스 만들어줬어요 오때용?',
#   '제주여행 맛집 ㅎㅎ',
#   '제주도 리트리버 잃어버리신분(주인찾음)',
#   '속초애견동반가능숙소어여들 오셔요!!',
#   '반려견 컨셉의 리조트를 소개드려요~ 모델하우스 다녀왔습니다.',
#   '강아지랑 여름 휴가',
#   '궁금한게있어서요ㅠ',
#   '여수 애견펜션 추천부탁드려요',
#   '양양 멍비치',
#   '애견동반가능한숙소',
#   '10살 포메랑 내일쯤 급으로 둘이 여행가려는데 추천부탁드려요 ( 뚜벅이예요)',
#   '제주도 애견동반숙소',
#   '서귀포시 쪽으로 애견동반숙소추천 해주실수있나요??',
#   '제주 여행 여독 ~^^',
#   '태안 메X벨X 풀빌라 가보신분 계신가요?',
#   '이번 여름 휴가 코스 추천 부탁드려요',
#   "소심해 단기 임보로 떠돌아다니는 '페퍼'를 장기임보 혹은 입양해주세요...",
#   '강릉 펫시터분 구합니다 ~ 6/30-7/1',
#   '양양 여행 (숙소후기)',
#   '강아지랑 제주도 한달살이 갈건데 강아지 갈수있는 해변이 있을까요?관광지 다닐땐 어떻게하시나요?',
#   '울강아지 여신 원피스 만들어줬어요 오때용?',
#   '제주여행 맛집 ㅎㅎ',
#   '제주도 리트리버 잃어버리신분(주인찾음)',
#   '속초애견동반가능숙소어여들 오셔요!!',
#   '반려견 컨셉의 리조트를 소개드려요~ 모델하우스 다녀왔습니다.',
#   '강아지랑 여름 휴가',
#   '궁금한게있어서요ㅠ',
#   '여수 애견펜션 추천부탁드려요',
#   '양양 멍비치',
#   '애견동반가능한숙소',
#   '10살 포메랑 내일쯤 급으로 둘이 여행가려는데 추천부탁드려요 ( 뚜벅이예요)',
#   '제주도 애견동반숙소',
#   '서귀포시 쪽으로 애견동반숙소추천 해주실수있나요??',
#   '제주 여행 여독 ~^^',
#   '태안 메X벨X 풀빌라 가보신분 계신가요?',
#   '이번 여름 휴가 코스 추천 부탁드려요',
# ...
