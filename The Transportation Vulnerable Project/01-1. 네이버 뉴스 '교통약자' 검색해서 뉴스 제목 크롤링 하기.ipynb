# %% [markdown]
# # 네이버 뉴스 교통약자 크롤링

# %%
import requests
from pandas import DataFrame
from bs4 import BeautifulSoup
import re
from datetime import datetime
import os

# %%
키워드 = '교통약자'

page_gubun = []
front = []
letsdigin = []
#bringpage " 가져오려는 페이지 수/10 "
bringpage = 1000
for i in range(bringpage):
#가져오고자 하는 페이지가 500개면 range(50)으로 설정
    페이지구분 = 1 + i*10
    page_url = f'https://search.naver.com/search.naver?where=news&sm=tab_pge&query={키워드}&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=48&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start={페이지구분}'
    page_gubun.append(page_url)

for i in range(bringpage):
    get_t_v = requests.get(page_gubun[i])
    gubun_soup = BeautifulSoup(get_t_v.content, 'html.parser')
    front.append(gubun_soup)

for f in range(bringpage):
    title_pre = front[f].select('div.group_news > ul > li')
    for k in range(10):
        digin = title_pre[k].select('div.news_area > a')
        val = digin[0].get_text()
        letsdigin.append(val)
for i in range(len(letsdigin)):
    letsdigin[i] = letsdigin[i].replace(', ', ' ').replace('.', ' ').replace('‘', ' ').replace('"', ' ').replace('·',' ').replace('…', ' ')
letsdigin
# Out:
# ['신협 교통약자 위해 5년간 차량 18대 기부',
#  "코레일 교통약자 위한 '맞춤형 스마트 내비게이션' 개발 착수",
#  '진주시 교통약자 바우처택시 50대 발대식 개최',
#  '신협 교통약자 위한  어부바 차량’ 기부',
#  "진주시 교통약자 위한 '바우처택시' 17일부터 본격 운행",
#  '한국철도 교통약자 위한  맞춤형 스마트 내비게이션’ 개발 착수',
#  "[뉴스1 PICK]서울시 교통약자 배려 '시옷형 주차장' 첫 운영",
#  '전주시설공단 노인 일자리로 교통약자 이동권 강화',
#  '조길형 시장 교통약자  이동권’ 행정 펼쳐',
#  "서울시 임산부 등 교통약자를 위한 '시옷 주차장' 도입 [뉴시스Pic]",
#  '신협 어부바 차량으로 교통 약자의 다리 역할',
#  "서울시 교통약자 배려 '시옷형' 공영 주차장 도입",
#  '전장연 지하철 시위     교통약자 이동권 보장하라 ',
#  "오세훈표 '약자 동행'  교통사고 보행 장애인 전동휠체어 지원",
#  '노인일자리로 교통약자 이동권 증진 및 사회적 가치 실현',
#  "복권기금 제주도 교통약자 이동지원 '앞장'",
#  '서천 서면 행복택시 교통약자의 든든한 버팀목으로',
#  "전주시설공단 '교통약자 이동권' 강화",
#  '무장애 관광 무장애 디자인  이동약자를 위한 제주의 실험',
#  '[B tv 부산뉴스] 사상구 교통약자 위한 저상버스 운행',
#  "진주시 교통약자 이동편의 위한 '바우처택시' 본격 운영",
#  '교통약자 배려한다던 서울 무료셔틀버스  저녁 주말엔 멈추고 9개 구는 아예   ',
#  " 천천히 걸어도 돼요  대학생이 만든 '교통 약자 배려' 디자인",
#  '일산 사회적 약자 교통안전망 구축 공조',
#  '화성시 교통사고 예방 사회적약자 자원봉사자 차량 무상점검',
#  '[들어보니] 교통약자 0 3%의 자유 | 빅벙커',
#  '통영 교통봉사대 교통약자 대상 찾아가는 교통안전교육',
# ...

# %%
len(letsdigin)
# Out:
# 10000

# %%
import pandas as pd

# %%
교통약자10000 = pd.DataFrame(letsdigin)

# %%
교통약자10000.to_csv("교통약자10000.csv", index=False, encoding="utf-8")
