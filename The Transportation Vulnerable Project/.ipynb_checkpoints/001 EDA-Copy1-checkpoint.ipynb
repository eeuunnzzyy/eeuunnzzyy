# %%
import pandas as pd
import numpy as np
import datetime
import glob

# %%
paths = glob.glob('master1_cleansing_map_before.csv')
paths[0]
# Out:
# 'master1_cleansing_map_before.csv'

# %%
paths[0]
# Out:
# 'master1_cleansing_map_before.csv'

# %%
df = pd.read_csv(paths[0])
df
# Out:
#           no cartype                 예정시간                 배차시간  \
# 0       7658    중형승합  2018-01-23 12:04:00  2018-01-23 12:18:42
# 1       1551    중형승합  2018-01-23 12:17:00  2018-01-23 12:50:37
# 2       5804    중형승합  2018-01-23 12:30:00  2018-01-23 12:17:06
# 3       7650    중형승합  2018-01-23 12:47:00  2018-01-23 12:51:19
# 4       1061    중형승합  2018-01-23 01:08:00  2018-01-23 01:44:17
# ...      ...     ...                  ...                  ...
# 407548  8579    대형승용  2022-06-24 07:00:00  2022-06-24 07:12:38
# 407549  8006    중형승합  2022-06-24 07:00:00  2022-06-24 07:09:10
# 407550  8261    중형승합  2022-06-24 07:00:00  2022-06-24 07:04:27
# 407551  1558    중형승합  2022-06-24 07:00:00  2022-06-24 08:06:22
# 407552  5725    중형승합  2022-06-24 07:00:00  2022-06-24 07:05:08
#
#                        승차시간 startpos1 startpos2 endpos1 endpos2
# 0       2018-01-23 12:34:08       성북구     장위제1동    동대문구     회기동
# 1       2018-01-23 01:19:22       중랑구     면목제7동     노원구    상계1동
# 2       2018-01-23 12:17:39       성북구     정릉제3동     강북구   수유제3동
# 3       2018-01-23 01:09:33       구로구     고척제2동     관악구     은천동
# 4       2018-01-23 02:06:53      동대문구       회기동     성북구   장위제2동
# ...                     ...       ...       ...     ...     ...
# 407548  2022-06-24 07:55:24       성북구     돈암제2동     강남구    대치4동
# 407549  2022-06-24 07:25:35       은평구       구산동     은평구     구산동
# 407550  2022-06-24 07:25:35       노원구      상계8동    영등포구    영등포동
# 407551  2022-06-24 06:55:01       성북구     길음제1동     강북구    번제1동
# 407552  2022-06-24 08:31:07       강동구     천호제2동     강동구   명일제1동
#
# [407553 rows x 9 columns]

# %% [markdown]
# # EDA - 차량번호별 배차량

# %%
배차량 = df['no'].value_counts()
배차량
# Out:
# 6278    1531
# 1559    1502
# 3265    1414
# 7582    1381
# 7658    1327
#         ...
# 5942       1
# 4985       1
# 8218       1
# 6063       1
# 6784       1
# Name: no, Length: 1086, dtype: int64

# %%
pd.DataFrame(배차량)
# Out:
#         no
# 6278  1531
# 1559  1502
# 3265  1414
# 7582  1381
# 7658  1327
# ...    ...
# 5942     1
# 4985     1
# 8218     1
# 6063     1
# 6784     1
#
# [1086 rows x 1 columns]

# %%
배차량.to_csv('배차량.csv', index = True, encoding = 'utf-8')

# %% [markdown]
# # 차량 고유번호별 구간을 벗어나는게 있는지 확인

# %%
df
# Out:
#           no cartype                 예정시간                 배차시간  \
# 0       7658    중형승합  2018-01-23 12:04:00  2018-01-23 12:18:42
# 1       1551    중형승합  2018-01-23 12:17:00  2018-01-23 12:50:37
# 2       5804    중형승합  2018-01-23 12:30:00  2018-01-23 12:17:06
# 3       7650    중형승합  2018-01-23 12:47:00  2018-01-23 12:51:19
# 4       1061    중형승합  2018-01-23 01:08:00  2018-01-23 01:44:17
# ...      ...     ...                  ...                  ...
# 407548  8579    대형승용  2022-06-24 07:00:00  2022-06-24 07:12:38
# 407549  8006    중형승합  2022-06-24 07:00:00  2022-06-24 07:09:10
# 407550  8261    중형승합  2022-06-24 07:00:00  2022-06-24 07:04:27
# 407551  1558    중형승합  2022-06-24 07:00:00  2022-06-24 08:06:22
# 407552  5725    중형승합  2022-06-24 07:00:00  2022-06-24 07:05:08
#
#                        승차시간 startpos1 startpos2 endpos1 endpos2
# 0       2018-01-23 12:34:08       성북구     장위제1동    동대문구     회기동
# 1       2018-01-23 01:19:22       중랑구     면목제7동     노원구    상계1동
# 2       2018-01-23 12:17:39       성북구     정릉제3동     강북구   수유제3동
# 3       2018-01-23 01:09:33       구로구     고척제2동     관악구     은천동
# 4       2018-01-23 02:06:53      동대문구       회기동     성북구   장위제2동
# ...                     ...       ...       ...     ...     ...
# 407548  2022-06-24 07:55:24       성북구     돈암제2동     강남구    대치4동
# 407549  2022-06-24 07:25:35       은평구       구산동     은평구     구산동
# 407550  2022-06-24 07:25:35       노원구      상계8동    영등포구    영등포동
# 407551  2022-06-24 06:55:01       성북구     길음제1동     강북구    번제1동
# 407552  2022-06-24 08:31:07       강동구     천호제2동     강동구   명일제1동
#
# [407553 rows x 9 columns]

# %%
outrange = []
for i in range(len(df)):
    if df['startpos1'][i] == df['endpos1'][i]:
        outrange.append(0)
    else:
        outrange.append(1)

# %%
df['outrange'] = outrange

# %%
df.head(7)
# Out:
#      no cartype                 예정시간                 배차시간  \
# 0  7658    중형승합  2018-01-23 12:04:00  2018-01-23 12:18:42
# 1  1551    중형승합  2018-01-23 12:17:00  2018-01-23 12:50:37
# 2  5804    중형승합  2018-01-23 12:30:00  2018-01-23 12:17:06
# 3  7650    중형승합  2018-01-23 12:47:00  2018-01-23 12:51:19
# 4  1061    중형승합  2018-01-23 01:08:00  2018-01-23 01:44:17
# 5  9568    중형승합  2018-01-23 01:11:00  2018-01-23 01:20:37
# 6  1551    중형승합  2018-01-23 01:22:00  2018-01-23 01:40:01
#
#                   승차시간 startpos1 startpos2 endpos1 endpos2  outrange
# 0  2018-01-23 12:34:08       성북구     장위제1동    동대문구     회기동         1
# 1  2018-01-23 01:19:22       중랑구     면목제7동     노원구    상계1동         1
# 2  2018-01-23 12:17:39       성북구     정릉제3동     강북구   수유제3동         1
# 3  2018-01-23 01:09:33       구로구     고척제2동     관악구     은천동         1
# 4  2018-01-23 02:06:53      동대문구       회기동     성북구   장위제2동         1
# 5  2018-01-23 01:55:30       마포구       도화동  부천시소사구   심곡본1동         1
# 6  2018-01-23 02:05:23       중랑구     상봉제1동     중랑구    신내2동         0

# %%
outrange_carno = df.groupby(df['no']).sum().sort_values(by = 'outrange')

# %%
len(df.groupby(df['no']).sum().sort_values(by = 'outrange'))
# Out:
# 1086

# %%
len(df['no'].unique())
# Out:
# 1086

# %%
len(df.groupby(df['no']).sum().sort_values(by = 'outrange'))/len(df['no'].unique())*100
#모든 차량이 구간을 벗어난적이 있음 (1번이상)
#더 자세히 보려면 위도경도 데이터를 얻어내서 다들 몇 km이상을 넘어갔는지 체크해보아야함 -> 근데 이미 있는 데이터
# Out:
# 100.0

# %%
outrange_carno = outrange_carno.rename_axis('carno').reset_index()

# %%
outrange_carno.head()
# Out:
#    carno  outrange
# 0   6063         0
# 1   6734         0
# 2   5942         0
# 3   4985         1
# 4   8218         1

# %%
outrange_carno.to_csv('outrange.csv', index = False, encoding = 'utf-8')

# %%
outrange_cartype = df.groupby(df['cartype']).sum().sort_values(by = 'outrange')

# %%
outrange_cartype.sort_values(by = 'outrange', ascending= False).to_csv('df_cartype_outrange_counts.csv', index = True, encoding= 'utf-8')

# %%
df['cartype'].value_counts().to_csv('df_cartype_counts.csv', index = True, encoding= 'utf-8')

# %% [markdown]
# # 시간구간별 수요량 확인

# %% [markdown]
# ## 시간별 (hour)

# %%
import datetime as dt

# %%
#컬럼 전체를 보여준다
pd.options.display.max_columns = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407553 entries, 0 to 407552
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   no         407553 non-null  int64
#  1   cartype    407553 non-null  object
#  2   예정시간       407553 non-null  object
#  3   배차시간       407553 non-null  object
#  4   승차시간       407553 non-null  object
#  5   startpos1  407553 non-null  object
#  6   startpos2  407553 non-null  object
#  7   endpos1    407553 non-null  object
#  8   endpos2    407553 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 28.0+ MB

# %%
df['예정시간'] = pd.to_datetime(df['예정시간'])
df['배차시간'] = pd.to_datetime(df['배차시간'])
df['승차시간'] = pd.to_datetime(df['승차시간'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407553 entries, 0 to 407552
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   no         407553 non-null  int64
#  1   cartype    407553 non-null  object
#  2   예정시간       407553 non-null  datetime64[ns]
#  3   배차시간       407553 non-null  datetime64[ns]
#  4   승차시간       407553 non-null  datetime64[ns]
#  5   startpos1  407553 non-null  object
#  6   startpos2  407553 non-null  object
#  7   endpos1    407553 non-null  object
#  8   endpos2    407553 non-null  object
# dtypes: datetime64[ns](3), int64(1), object(5)
# memory usage: 28.0+ MB

# %%
df['y_year'] = df['예정시간'].dt.year
df['y_month'] = df['예정시간'].dt.month
df['y_ym'] = df['예정시간'].astype(str).str[:7]
df['y_ymd'] = df['예정시간'].astype(str).str[:10]
df['y_day'] = df['예정시간'].dt.day
df['y_dow'] = df['예정시간'].dt.dayofweek #요일
df['y_hour'] = df['예정시간'].dt.hour
df['y_minute'] = df['예정시간'].dt.minute

# %%
df['b_ymd'] = df['배차시간'].astype(str).str[:10]
df['b_day'] = df['배차시간'].dt.day
df['b_dow'] = df['배차시간'].dt.dayofweek #요일
df['b_hour'] = df['배차시간'].dt.hour
df['b_minute'] = df['배차시간'].dt.minute
df['s_ymd'] = df['승차시간'].astype(str).str[:10]
df['s_day'] = df['승차시간'].dt.day
df['s_dow'] = df['승차시간'].dt.dayofweek #요일
df['s_hour'] = df['승차시간'].dt.hour
df['s_minute'] = df['승차시간'].dt.minute

# %%
#예정보다 배차까지 x분 소요
df['배차-예정'] = (df['b_hour']*60 + df['b_minute']) - (df['y_hour']*60 + df['y_minute'])

# %%
#배차보다 승차까지 y분 소요
df['승차-배차'] = (df['s_hour']*60 + df['s_minute']) - (df['b_hour']*60 + df['b_minute'])

# %%
df
# Out:
#
#         s_hour  s_minute  배차-예정  승차-배차
# 0           12        34     14     16
# 1            1        19     33   -691
# 2           12        17    -13      0
# 3            1         9      4   -702
# 4            2         6     36     22
# ...        ...       ...    ...    ...
# 407548       7        55     12     43
# 407549       7        25      9     16
# 407550       7        25      4     21
# 407551       6        55     66    -71
# 407552       8        31      5     86
#
# [407553 rows x 29 columns]

# %%
pd.set_option('display.max_row', 500)

# %%
df['y_dow'].value_counts()
#주말, 주중 격차 존재하지 않음
# Out:
# 5    58266
# 0    58265
# 3    58265
# 2    58265
# 1    58263
# 4    58214
# 6    58015
# Name: y_dow, dtype: int64

# %%
df['y_hour'].value_counts().sort_values(ascending = False).to_csv('y_hour.csv', index = True, encoding= 'utf-8')

# %%
df['b_hour'].value_counts().sort_values(ascending = False).to_csv('b_hour.csv', index = True, encoding= 'utf-8')

# %%
df['s_hour'].value_counts().sort_values(ascending = False).to_csv('s_hour.csv', index = True, encoding= 'utf-8')

# %% [markdown]
# ## 요일별 (day of week)

# %%
df['y_dow'].value_counts().sort_values(ascending = False).to_csv('y_dow.csv', index = True, encoding= 'utf-8')

# %%
df['b_dow'].value_counts().sort_values(ascending = False).to_csv('b_dow.csv', index = True, encoding= 'utf-8')

# %%
df['s_dow'].value_counts().sort_values(ascending = False).to_csv('s_dow.csv', index = True, encoding= 'utf-8')

# %% [markdown]
# ## 월별 (Month) 평균으로 집계해야함 2022년에는 1-6월까지 있으므로

# %%
df[df['y_year'] != 2022]['y_month'].value_counts().to_csv('y_month.csv', index = True, encoding = 'utf-8')

# %% [markdown]
# ## 년별 수요량

# %%
df[df['y_year'] != 2022]['y_year'].value_counts().to_csv('y_year.csv', index = True, encoding = 'utf-8')

# %% [markdown]
# ## 년월별 수요량

# %%
df[df['y_day'] <= 28]['y_ym'].value_counts().sort_values(ascending= False).to_csv('y_ym.csv', index = True, encoding = 'utf-8')

# %% [markdown]
# # 추가 분석 , 아래의 그래프가 의미하는게 뭔지 파악해야함

# %%
df.groupby(df['y_month']).mean()
# Out:
#                   no       y_year      y_day     y_dow    y_hour   y_minute  \
# y_month
# 1        9696.509186  2020.000104  16.000000  2.993652  6.823232  14.611380
# 2        9554.865658  2020.000684  14.604753  3.013847  6.834231  14.942730
# 3        9249.028918  2020.000155  16.000285  2.987122  6.823824  15.558691
# 4        9188.443838  2020.000161  15.499692  2.986639  6.751466  14.282834
# 5        8554.439798  2020.000000  16.000000  3.019355  6.730587  13.442441
# 6        8695.417552  2019.928740  15.059060  3.012699  6.674393  12.623929
# 7        6435.889655  2019.500000  16.000000  2.959677  6.652999  13.079544
# 8        5946.396198  2019.500000  16.000000  3.024194  6.805415  12.475774
# 9        5707.737885  2019.500000  15.500000  3.008333  6.867035  13.404953
# 10       5816.596029  2019.500000  16.000000  3.000000  6.811601  12.630619
# 11       5765.324398  2019.500000  15.500000  2.991667  6.719880  11.373896
# 12       6010.074589  2019.500000  16.000453  2.975806  6.833592  13.186455
#
#              b_day     b_dow    b_hour   b_minute      s_day     s_dow  \
# y_month
# 1        16.004249  2.967973  6.896380  20.568030  16.004742  2.967585
# 11      15.238193  5.367556  9.976386  28.403491  16.680698  1.332649
# 12      15.866039  2.965990  7.457793  27.827991  15.679227  3.267678
#
#           s_hour   s_minute       배차-예정       승차-배차
# y_hour
# 1       4.692873  27.645702   41.413946  178.903435
# 2       5.037567  28.285232   16.508448  164.451004
# 3       5.474557  27.986662   10.790518  133.156467
# 4       6.242747  27.161232   15.861525  115.030011
# 5       6.783173  26.137400   35.076505   69.024943
# 6       7.169220  26.313883   49.804522   24.307075
# 7       7.042872  27.457866   15.796155    7.962339
# 8       7.992256  29.171386   10.392102   -1.799715
# 9       8.355140  28.617989    7.929392  -43.651717
# 10      8.031242  30.352453    3.493044 -108.115206
# 11      2.373717  27.781314  -60.880903 -456.782341
# 12      4.738561  28.080866 -271.641913 -162.901028

# %% [markdown]
# # 클러스터링을 이용해서 장콜 러쉬아워 구간 얻어내기

# %% [markdown]
# ### 예정시간 기준

# %%
df['y_hour'].value_counts()
# Out:
# 7     255223
# 8      42874
# 5      36965
# 9      16188
# 4      15028
# 3       8922
# 6       8226
# 12      8174
# 1       5851
# 2       5031
# 10      4097
# 11       974
# Name: y_hour, dtype: int64

# %%
c = df[['y_hour', 'startpos2', '배차-예정', '승차-배차']]

# %%
c['startpos2'].value_counts().index
# Out:
# Index(['하계1동', '등촌제3동', '가양제2동', '가양제1동', '월계2동', '상계1동', '세곡동', '성산제2동',
#        '수서동', '오류제2동',
#        ...
#        '비산1동', '화정1동', '회천4동', '학온동', '상1동', '송산동', '안양4동', '심곡1동', '광적면',
#        '석수2동'],
#       dtype='object', length=557)

# %%
c[c['startpos2'] == c['startpos2'].value_counts().index[1] ]
# Out:
#         y_hour startpos2  배차-예정  승차-배차
# 17           3     등촌제3동     15      7
# 107          6     등촌제3동     77     10
# 118          6     등촌제3동     88     17
# 119          6     등촌제3동     88     17
# 184          7     등촌제3동     62     22
# ...        ...       ...    ...    ...
# 407208       7     등촌제3동     10     34
# 407261       7     등촌제3동      1     44
# 407459       7     등촌제3동      7     11
# 407483       7     등촌제3동      4      3
# 407514       7     등촌제3동      2     26
#
# [6429 rows x 4 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
#인덱스에 숫자 부여
indexing = []
for i in range(len(c)):
    for j in range(len(c['startpos2'].value_counts())):
        if c['startpos2'][i] == c['startpos2'].value_counts().index[j]:
            val = j
            indexing.append(val)
        else:
            val = 'error'
            indexing.append(val)

# %%
c

# %%
c_scaled = sc.fit_transform(c)
pd.DataFramae(c_scaled)

# %%
kmeans = KMeans(n_clusters = 4, random_state = 0)
cluster = kmeans.fit(c_scaled)

# %%
c['cluster'] = clusters.labels_
c.head()

# %%
cc.groupby('cluster').count()

# %%
c.groupby('cluster').mean()

# %%
#차원축소
from sklearn.decomposition import PCA
X = c_scaled.copy()

#객체
pca = PCA(n_components= 2)
pca.fit(X)
x_pca = pca.transform(X)

# %%
#make it visible to make a dataframe
pca_df = pd.DataFrame(x_pca)
pca_df

# %%
pca_df['cluster'] = c['cluster']

# %%
import seaborn as sns

# %%
axs = plt.subplots()

# %%
axs = sns.scatterplot(0, 1, hue = 'cluster', data = pca_df)
