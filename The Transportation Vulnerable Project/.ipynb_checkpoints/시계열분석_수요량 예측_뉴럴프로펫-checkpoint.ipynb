# %%
# !pip install neuralprophet
# Out:
# Collecting neuralprophet
#   Downloading neuralprophet-0.3.2-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 4.5 MB/s eta 0:00:011
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (3.4.3)
# Collecting torch>=1.4.0
#   Downloading torch-1.12.0-cp39-none-macosx_10_9_x86_64.whl (133.6 MB)
#      |████████████████████████████████| 133.6 MB 1.0 MB/s eta 0:00:01    |███████████▍                    | 47.5 MB 1.1 MB/s eta 0:01:21     |█████████████▎                  | 55.2 MB 1.0 MB/s eta 0:01:16██████████████████            | 83.3 MB 1.0 MB/s eta 0:00:48
# Requirement already satisfied: holidays>=0.11.3.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (2.8.2)
# Requirement already satisfied: pandas>=1.0.4 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (1.3.4)
# Requirement already satisfied: ipywidgets>=7.5.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (7.6.5)
# Collecting dataclasses>=0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (0.0.9)
# Requirement already satisfied: tqdm>=4.50.2 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (4.64.0)
# Requirement already satisfied: numpy>=1.15.4 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (1.23.0)
# Collecting torch-lr-finder>=0.2.1
#   Downloading torch_lr_finder-0.2.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: convertdate>=2.1.2 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from neuralprophet) (2.4.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from convertdate>=2.1.2->neuralprophet) (0.5.11)
# Requirement already satisfied: hijri-converter in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from holidays>=0.11.3.1->neuralprophet) (2.2.4)
# Requirement already satisfied: korean-lunar-calendar in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from holidays>=0.11.3.1->neuralprophet) (0.2.1)
# Requirement already satisfied: ipython>=4.0.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.1->neuralprophet) (7.29.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.1->neuralprophet) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.1->neuralprophet) (6.4.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.1->neuralprophet) (5.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.1->neuralprophet) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.1->neuralprophet) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (6.1)
# Requirement already satisfied: appnope in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (6.1.12)
# Requirement already satisfied: pygments in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (58.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (3.0.20)
# Requirement already satisfied: pickleshare in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.7.5)
# Requirement already satisfied: backcall in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (4.8.0)
# Requirement already satisfied: decorator in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (4.8.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from LunarCalendar>=0.0.9->neuralprophet) (4.1.3)
# Requirement already satisfied: pytz in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from LunarCalendar>=0.0.9->neuralprophet) (2021.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->neuralprophet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->neuralprophet) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->neuralprophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->neuralprophet) (0.10.0)
# Requirement already satisfied: six in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.0.0->neuralprophet) (1.16.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.2.5)
# Requirement already satisfied: typing-extensions in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.4.0->neuralprophet) (3.10.0.2)
# Requirement already satisfied: packaging in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from torch-lr-finder>=0.2.1->neuralprophet) (21.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (6.4.5)
# Requirement already satisfied: nbconvert in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (6.1.0)
# Requirement already satisfied: jinja2 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.11.0)
# Requirement already satisfied: argon2-cffi in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.14.6)
# Requirement already satisfied: pycparser in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (2.0.1)
# Requirement already satisfied: defusedxml in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.3)
# Requirement already satisfied: bleach in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.8.4)
# Requirement already satisfied: testpath in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.0)
# Requirement already satisfied: async-generator in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.5.1)
# Requirement already satisfied: webencodings in /Users/jeon-eunji/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.1)
# Installing collected packages: torch, torch-lr-finder, dataclasses, neuralprophet
# Successfully installed dataclasses-0.6 neuralprophet-0.3.2 torch-1.12.0 torch-lr-finder-0.2.1

# %%
#패키지 임포트
import pandas as pd
from neuralprophet import NeuralProphet, set_log_level
set_log_level("ERROR")

# %%
df = pd.read_csv('timeseriesanaylsis.csv')
df
# Out:
#                        예정시간 startpos1 startpos2
# 0       2018-01-23 00:04:00       성북구     장위제1동
# 1       2018-01-23 00:17:00       중랑구     면목제7동
# 2       2018-01-23 00:17:06       성북구     정릉제3동
# 3       2018-01-23 00:47:00       구로구     고척제2동
# 4       2018-01-23 01:08:00      동대문구       회기동
# ...                     ...       ...       ...
# 407548  2022-06-24 07:00:00       성북구     돈암제2동
# 407549  2022-06-24 07:00:00       은평구       구산동
# 407550  2022-06-24 07:00:00       노원구      상계8동
# 407551  2022-06-24 06:55:01       성북구     길음제1동
# 407552  2022-06-24 07:00:00       강동구     천호제2동
#
# [407553 rows x 3 columns]

# %%
import pandas as pd

# %%
df['예정시간'] = pd.to_datetime(df['예정시간'])

# %%
df['예정시간'] = pd.to_datetime(df['예정시간'].dt.strftime('%Y-%m-%d'))

# %%
df = df[['예정시간', 'startpos1', 'startpos2']]

# %%
df
# Out:
#              예정시간 startpos1 startpos2
# 0      2018-01-23       성북구     장위제1동
# 1      2018-01-23       중랑구     면목제7동
# 2      2018-01-23       성북구     정릉제3동
# 3      2018-01-23       구로구     고척제2동
# 4      2018-01-23      동대문구       회기동
# ...           ...       ...       ...
# 407548 2022-06-24       성북구     돈암제2동
# 407549 2022-06-24       은평구       구산동
# 407550 2022-06-24       노원구      상계8동
# 407551 2022-06-24       성북구     길음제1동
# 407552 2022-06-24       강동구     천호제2동
#
# [407553 rows x 3 columns]

# %%
df[df['startpos1'] == '강서구'].groupby('예정시간').count()['startpos1'].describe()
# Out:
# count    1637.000000
# mean       22.926695
# std         4.449197
# min        10.000000
# 25%        20.000000
# 50%        23.000000
# 75%        26.000000
# max        40.000000
# Name: startpos1, dtype: float64

# %%
df[df['startpos1'] == '강서구'].groupby('예정시간').count()['startpos1'].describe()
df.head()
# Out:
#         예정시간 startpos1 startpos2
# 0 2018-01-23       성북구     장위제1동
# 1 2018-01-23       중랑구     면목제7동
# 2 2018-01-23       성북구     정릉제3동
# 3 2018-01-23       구로구     고척제2동
# 4 2018-01-23      동대문구       회기동

# %%
data = df.rename(columns = {'예정시간' : 'date'})
data[data['startpos1'] == '강서구'].groupby('date').count().describe()['startpos1']
data
# Out:
#              date startpos1 startpos2
# 0      2018-01-23       성북구     장위제1동
# 1      2018-01-23       중랑구     면목제7동
# 2      2018-01-23       성북구     정릉제3동
# 3      2018-01-23       구로구     고척제2동
# 4      2018-01-23      동대문구       회기동
# ...           ...       ...       ...
# 407548 2022-06-24       성북구     돈암제2동
# 407549 2022-06-24       은평구       구산동
# 407550 2022-06-24       노원구      상계8동
# 407551 2022-06-24       성북구     길음제1동
# 407552 2022-06-24       강동구     천호제2동
#
# [407553 rows x 3 columns]

# %%
data = data[data['startpos1'] == '강서구'].groupby('date').count()

# %%
data = data.reset_index()[['date', 'startpos1']]

# %%
data
# Out:
#            date  startpos1
# 0    2018-01-01         23
# 1    2018-01-02         24
# 2    2018-01-03         18
# 3    2018-01-04         21
# 4    2018-01-05         23
# ...         ...        ...
# 1632 2022-06-21         27
# 1633 2022-06-22         22
# 1634 2022-06-23         26
# 1635 2022-06-24         17
# 1636 2022-06-25         25
#
# [1637 rows x 2 columns]

# %% [markdown]
# # 데이터 전처리 및 모델 학습

# %%
#train test split
cutoff = "2021-01-01"
train_df = data[data['date']<cutoff]
test_df = data[data['date']>=cutoff]

# %%
#전용 train, test 데이터 생성
train = pd.DataFrame({"ds": train_df["date"], "y": train_df["startpos1"]})
test = pd.DataFrame({"ds": test_df["date"], "y": test_df["startpos1"]})

# %%
train.head()
# Out:
#           ds   y
# 0 2018-01-01  23
# 1 2018-01-02  24
# 2 2018-01-03  18
# 3 2018-01-04  21
# 4 2018-01-05  23

# %%
train['ds']
# Out:
# 0      2018-01-01
# 1      2018-01-02
# 2      2018-01-03
# 3      2018-01-04
# 4      2018-01-05
#           ...
# 1091   2020-12-27
# 1092   2020-12-28
# 1093   2020-12-29
# 1094   2020-12-30
# 1095   2020-12-31
# Name: ds, Length: 1096, dtype: datetime64[ns]

# %%
#train = train.resample('W-MON', label='right', closed = 'right', on='ds').sum().reset_index().sort_values(by='ds')
#test = test.resample('W-MON', label='right', closed = 'right', on='ds').sum().reset_index().sort_values(by='ds')

# %%
#모델 설정
m = NeuralProphet(
    learning_rate=0.1,
    weekly_seasonality=False,
    daily_seasonality=False
)

# %%
#모델 학습
metrics = m.fit(train, freq = 'D')

# %%
#학습 데이터셋 예측 결과 시각화
train_pred = m.predict(train)
#fig = m.plot(train_pred)
fig1 = m.plot(train_pred[-30*24*6:])
#fig2 = m.plot(train_pred[-7*24*6:])
#comp = m.plot_components(train_pred)
param = m.plot_parameters()

# %%
#테스트 데이터셋 예측 결과 시각화
test_pred = m.predict(test)
fig = m.plot(test_pred)
#fig1 = m.plot(test_pred[-14*24*6:])
#fig2 = m.plot(test_pred[-7*24*6:])
#comp = m.plot_components(test_pred)
param = m.plot_parameters()

# %%
df_future = m.make_future_dataframe(test, periods=360)
forecast = m.predict(df_future)
fig_forecast = m.plot(forecast)

# %%
all_pred = pd.concat([train_pred, test_pred, forecast])
fig_all_pred = m.plot(all_pred)

# %% [markdown]
# # 성능평가

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

col = "Appliances"

#학습 데이터셋 검증
pred2 = train_pred["y"]
test2 = train_pred['yhat1']
print("============== {} Evaluate Result============".format(col))
print("MAE :", mean_absolute_error(test2, pred2))
print("MSE :", mean_squared_error(test2, pred2))
print("RMSE :", (mean_squared_error(test2, pred2, squared=False)))
print("MAPE :", mean_absolute_percentage_error(test2, pred2))
# Out:
# ============== Appliances Evaluate Result============
# MAE : 3.159737277204973
# MSE : 16.1138168649432
# RMSE : 4.014201896385282
# MAPE : 0.14294944506942228

# %%
#테스트 데이터셋 검증
pred2 = test_pred["y"]
test2 = test_pred['yhat1']
print("============== {} Evaluate Result============".format(col))
print("MAE :", mean_absolute_error(test2, pred2))
print("MSE :", mean_squared_error(test2, pred2))
print("RMSE :", (mean_squared_error(test2, pred2))**0.5)
print("MAPE :", mean_absolute_percentage_error(test2, pred2))
# Out:
# ============== Appliances Evaluate Result============
# MAE : 4.36962794023609
# MSE : 28.12372521805354
# RMSE : 5.303180669942666
# MAPE : 0.15963802163678914

# %% [markdown]
# # 노원구

# %%
data = df.rename(columns = {'예정시간' : 'date'})
data1 = data[data['startpos1'] == '노원구'].groupby('date').count()

# %%
data1 = data1.reset_index()[['date', 'startpos1']]

# %%
data1.describe()
# Out:
#          startpos1
# count  1637.000000
# mean     26.931582
# std       5.351024
# min      13.000000
# 25%      23.000000
# 50%      26.000000
# 75%      30.000000
# max      52.000000

# %%
#train test split
cutoff = "2020-06-01"
train_df = data1[data1['date']<cutoff]
test_df = data1[data1['date']>=cutoff]
#전용 train, test 데이터 생성
train = pd.DataFrame({"ds": train_df["date"], "y": train_df["startpos1"]})
test = pd.DataFrame({"ds": test_df["date"], "y": test_df["startpos1"]})

# %%
#모델 설정
m = NeuralProphet(
    learning_rate=0.1,
    weekly_seasonality=False,
    daily_seasonality=False
)

# %%
#모델 학습
metrics = m.fit(train, freq = 'D')

# %%
#학습 데이터셋 예측 결과 시각화
train_pred = m.predict(train)
#fig = m.plot(train_pred)
fig1 = m.plot(train_pred[-30*24*6:])
#fig2 = m.plot(train_pred[-7*24*6:])
#comp = m.plot_components(train_pred)
param = m.plot_parameters()

# %%
#테스트 데이터셋 예측 결과 시각화
test_pred = m.predict(test)
fig = m.plot(test_pred)
#fig1 = m.plot(test_pred[-14*24*6:])
#fig2 = m.plot(test_pred[-7*24*6:])
#comp = m.plot_components(test_pred)
param = m.plot_parameters()

# %%
df_future = m.make_future_dataframe(test, periods=360)
forecast = m.predict(df_future)
fig_forecast = m.plot(forecast)

# %%
all_pred = pd.concat([train_pred, test_pred, forecast])
fig_all_pred = m.plot(all_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

col = "Appliances"

#학습 데이터셋 검증
pred2 = train_pred["y"]
test2 = train_pred['yhat1']
print("============== {} Evaluate Result============".format(col))
print("MAE :", mean_absolute_error(test2, pred2))
print("MSE :", mean_squared_error(test2, pred2))
print("RMSE :", (mean_squared_error(test2, pred2, squared=False)))
print("MAPE :", mean_absolute_percentage_error(test2, pred2))
# Out:
# ============== Appliances Evaluate Result============
# MAE : 3.90050255522436
# MSE : 25.765897813842262
# RMSE : 5.076011998985253
# MAPE : 0.15076810600649954

# %%
#테스트 데이터셋 검증
pred2 = test_pred["y"]
test2 = test_pred['yhat1']
print("============== {} Evaluate Result============".format(col))
print("MAE :", mean_absolute_error(test2, pred2))
print("MSE :", mean_squared_error(test2, pred2))
print("RMSE :", (mean_squared_error(test2, pred2))**0.5)
print("MAPE :", mean_absolute_percentage_error(test2, pred2))
# Out:
# ============== Appliances Evaluate Result============
# MAE : 5.233995303728722
# MSE : 39.21635737355306
# RMSE : 6.262296493583888
# MAPE : 0.16843341742281695

# %%
data1.describe()
# Out:
#          startpos1
# count  1637.000000
# mean     26.931582
# std       5.351024
# min      13.000000
# 25%      23.000000
# 50%      26.000000
# 75%      30.000000
# max      52.000000

# %% [markdown]
# # 서대문구

# %%
data = df.rename(columns = {'예정시간' : 'date'})
data2 = data[data['startpos1'] == '서대문구'].groupby('date').count()

# %%
data2 = data2.reset_index()[['date', 'startpos1']]

# %%
#train test split
cutoff = "2021-03-01"
train_df = data2[data2['date']<cutoff]
test_df = data2[data2['date']>=cutoff]
#전용 train, test 데이터 생성
train = pd.DataFrame({"ds": train_df["date"], "y": train_df["startpos1"]})
test = pd.DataFrame({"ds": test_df["date"], "y": test_df["startpos1"]})

# %%
#모델 설정
m = NeuralProphet(
    learning_rate=0.1,
    weekly_seasonality=False,
    daily_seasonality=False
)

# %%
#모델 학습
metrics = m.fit(train, freq = 'D')

# %%
#학습 데이터셋 예측 결과 시각화
train_pred = m.predict(train)
#fig = m.plot(train_pred)
fig1 = m.plot(train_pred[-30*24*6:])
#fig2 = m.plot(train_pred[-7*24*6:])
#comp = m.plot_components(train_pred)
param = m.plot_parameters()

# %%
#테스트 데이터셋 예측 결과 시각화
test_pred = m.predict(test)
fig = m.plot(test_pred)
#fig1 = m.plot(test_pred[-14*24*6:])
#fig2 = m.plot(test_pred[-7*24*6:])
#comp = m.plot_components(test_pred)
param = m.plot_parameters()

# %%
df_future = m.make_future_dataframe(test, periods=360)
forecast = m.predict(df_future)
fig_forecast = m.plot(forecast)

# %%
all_pred = pd.concat([train_pred, test_pred, forecast])
fig_all_pred = m.plot(all_pred)

# %%
col = "Appliances"

#학습 데이터셋 검증
pred2 = train_pred["y"]
test2 = train_pred['yhat1']
print("============== {} Evaluate Result============".format(col))
print("MAE :", mean_absolute_error(test2, pred2))
print("MSE :", mean_squared_error(test2, pred2))
print("RMSE :", (mean_squared_error(test2, pred2, squared=False)))
print("MAPE :", mean_absolute_percentage_error(test2, pred2))
# Out:
# ============== Appliances Evaluate Result============
# MAE : 2.2892356322784173
# MSE : 8.293205256425642
# RMSE : 2.8797925717706896
# MAPE : 0.23432368611895377

# %%
#테스트 데이터셋 검증
pred2 = test_pred["y"]
test2 = test_pred['yhat1']
print("============== {} Evaluate Result============".format(col))
print("MAE :", mean_absolute_error(test2, pred2))
print("MSE :", mean_squared_error(test2, pred2))
print("RMSE :", (mean_squared_error(test2, pred2))**0.5)
print("MAPE :", mean_absolute_percentage_error(test2, pred2))
# Out:
# ============== Appliances Evaluate Result============
# MAE : 2.730605757434691
# MSE : 11.972641159273033
# RMSE : 3.4601504532712206
# MAPE : 0.32891815870036417

# %%
data2.describe()
# Out:
#          startpos1
# count  1637.000000
# mean      9.792914
# std       3.076927
# min       2.000000
# 25%       8.000000
# 50%      10.000000
# 75%      12.000000
# max      22.000000
