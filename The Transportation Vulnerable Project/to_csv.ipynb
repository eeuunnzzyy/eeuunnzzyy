# %%
import pandas as pd
import seaborn as sns
import glob

# %%
paths = glob.glob("*.*")
df = pd.read_csv(paths[1], encoding= 'cp949')

# %%
for i in range(0, 156):
    df['소재지지번주소'][i] = df['소재지지번주소'][i].split(' ')[0]
df
# Out:
# /var/folders/3q/y966c1fj3lndmps8kk3plpy40000gn/T/ipykernel_41603/1706167971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['소재지지번주소'][i] = df['소재지지번주소'][i].split(' ')[0]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3q/y966c1fj3lndmps8kk3plpy40000gn/T/ipykernel_41603/1706167971.py in <module>
#       1 for i in range(0, 156):
# ----> 2     df['소재지지번주소'][i] = df['소재지지번주소'][i].split(' ')[0]
#       3 df
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df.to_csv('전국교통약자이동지원센터정보표준데이터_시도추가.csv', encoding = cp949)
# Out:
#              교통약자이동지원센터명                                     소재지도로명주소  \
# 0        완도군 개인택시 지부(위탁)                          완도군 완도읍 개포로130번길 15
# 1         고양시 교통약자이동지원센터                          경기도 고양시 일산동구 강송로 14
# 2        경북지체장애인협회 봉화군지회                        경상북도 봉화군 봉화읍 내성천2길 93
# 3    (사)강원도지체장애인협회 평창군지회                      강원도 평창군 진부면 진벌1길 144-19
# 4      사)충남지체장애인협회 당진시지회                             충청남도 당진시 백암1길 61
# ..                   ...                                          ...
# 151           교통약자이동지원센터                          경기도 포천시 군내면 청성로 112
# 152    강원도 교통약자 광역이동지원센터                             강원도 춘천시 봉의동 중앙로1
# 153       경남지체장애인협회합천군지회                          경상남도 합천군 합천읍 남정길 79
# 154        연천군교통약자이동지원센터                          경기도 연천군 전곡읍 전곡로 193
# 155      구례군 교통약자 이동지원센터  전라남도 구례군 구례읍 서시천로 106 (사)전남지체장애인협회 구례군지회 1층
#
#                                            소재지지번주소         위도          경도  \
# ...

# %%
paths[1]
# Out:
# '전국교통약자이동지원센터정보표준데이터.csv'
