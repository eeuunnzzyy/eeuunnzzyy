# %%
import glob
import pandas as pd
import datetime as dt
import numpy as np

# %%
df = pd.read_csv('master_final_220706.csv')

# %%
df['예정시간'] = pd.to_datetime(df['예정시간'])
df['배차시간'] = pd.to_datetime(df['배차시간'])
df['승차시간'] = pd.to_datetime(df['승차시간'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407553 entries, 0 to 407552
# Data columns (total 17 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  407553 non-null  int64
#  1   cartype     407553 non-null  object
#  2   예정시간        407553 non-null  datetime64[ns]
#  3   배차시간        407553 non-null  datetime64[ns]
#  4   승차시간        407553 non-null  datetime64[ns]
#  5   startpos1   407553 non-null  object
#  6   startpos2   407553 non-null  object
#  7   endpos1     407553 non-null  object
#  8   endpos2     407553 non-null  object
#  9   start_lat   407553 non-null  float64
#  10  start_lng   407553 non-null  float64
#  11  end_lat     407553 non-null  float64
#  12  end_lng     407553 non-null  float64
#  13  direction   407553 non-null  object
#  14  distance    407553 non-null  int64
#  15  duration    407553 non-null  float64
#  16  taxiFare    407553 non-null  int64
# ...

# %%
df['y_year'] = df['예정시간'].dt.year
df['y_month'] = df['예정시간'].dt.month
df['y_ym'] = df['예정시간'].astype(str).str[:7]
df['y_ymd'] = df['예정시간'].astype(str).str[:10]
df['y_day'] = df['예정시간'].dt.day
df['y_dow'] = df['예정시간'].dt.dayofweek #요일
df['y_hour'] = df['예정시간'].dt.hour
df['y_minute'] = df['예정시간'].dt.minute
df['b_ymd'] = df['배차시간'].astype(str).str[:10]
df['b_day'] = df['배차시간'].dt.day
df['b_dow'] = df['배차시간'].dt.dayofweek #요일
df['b_hour'] = df['배차시간'].dt.hour
df['b_minute'] = df['배차시간'].dt.minute
df['s_ymd'] = df['승차시간'].astype(str).str[:10]
df['s_day'] = df['승차시간'].dt.day
df['s_dow'] = df['승차시간'].dt.dayofweek #요일
df['s_hour'] = df['승차시간'].dt.hour
df['s_minute'] = df['승차시간'].dt.minute

# %%
df
# Out:
#         Unnamed: 0 cartype                예정시간                배차시간  \
# 0                0    중형승합 2018-01-23 00:04:00 2018-01-23 00:18:42
# 1                1    중형승합 2018-01-23 00:17:00 2018-01-23 00:50:37
# 2                2    중형승합 2018-01-23 00:30:00 2018-01-23 00:17:06
# 3                3    중형승합 2018-01-23 00:47:00 2018-01-23 00:51:19
# 4                4    중형승합 2018-01-23 01:08:00 2018-01-23 01:44:17
# ...            ...     ...                 ...                 ...
# 407548      407548    대형승용 2022-06-24 07:00:00 2022-06-24 07:12:38
# 407549      407549    중형승합 2022-06-24 07:00:00 2022-06-24 07:09:10
# 407550      407550    중형승합 2022-06-24 07:00:00 2022-06-24 07:04:27
# 407551      407551    중형승합 2022-06-24 07:00:00 2022-06-24 08:06:22
# 407552      407552    중형승합 2022-06-24 07:00:00 2022-06-24 07:05:08
#
#                       승차시간 startpos1 startpos2 endpos1 endpos2   start_lat  \
# 0      2018-01-23 00:34:08       성북구     장위제1동    동대문구     회기동  127.043713
# ...

# %%
df['배차-예정'] = (df['b_hour']*60 + df['b_minute']) - (df['y_hour']*60 + df['y_minute'])
df['승차-배차'] = (df['s_hour']*60 + df['s_minute']) - (df['b_hour']*60 + df['b_minute'])
df['승차-예정'] = (df['s_hour']*60 + df['s_minute']) - (df['y_hour']*60 + df['y_minute'])

# %%
df[df['배차-예정'] < 0].head()
# Out:
#     Unnamed: 0 cartype                예정시간                배차시간  \
# 25          25    중형승합 2018-01-23 04:30:00 2018-01-23 04:00:59
# 27          27    중형승합 2018-01-23 04:40:00 2018-01-23 04:02:59
# 28          28    중형승합 2018-01-23 04:40:00 2018-01-23 03:57:30
# 31          31    중형승합 2018-01-23 05:00:00 2018-01-23 04:36:05
# 41          41    중형승합 2018-01-23 05:20:00 2018-01-23 05:15:49
#
#                   승차시간 startpos1 startpos2 endpos1 endpos2   start_lat  ...  \
# 25 2018-01-23 04:47:02       구로구     오류제1동    영등포구   대림제3동  126.845201  ...
# 27 2018-01-23 04:43:09       종로구       부암동     종로구   창신제1동  126.964100  ...
# 28 2018-01-23 04:44:27       송파구       장지동     강동구   명일제1동  127.135400  ...
# 31 2018-01-23 05:06:18       노원구    중계2.3동     노원구  상계6.7동  127.068713  ...
# 41 2018-01-23 05:46:28       성북구       삼선동    서대문구     충현동  127.014630  ...
#
#     b_hour  b_minute       s_ymd s_day  s_dow  s_hour  s_minute  배차-예정  승차-배차  \
# ...

# %%
con = (df['승차-예정'] < 0) & (df['배차-예정'] < 0)

# %%
dinex = df[con].index

# %%
con1 = (df1['승차-예정'] < 0) & (df1['배차-예정'] < 0)
dinex1 = df1[con1].index

# %%
df1.head(2)
# Out:
#    Unnamed: 0 cartype                예정시간                배차시간  \
# 0           0    중형승합 2018-01-23 00:04:00 2018-01-23 00:18:42
# 1           1    중형승합 2018-01-23 00:17:00 2018-01-23 00:50:37
#
#                  승차시간 startpos1 startpos2 endpos1 endpos2   start_lat  ...  \
# 0 2018-01-23 00:34:08       성북구     장위제1동    동대문구     회기동  127.043713  ...
# 1 2018-01-23 01:19:22       중랑구     면목제7동     노원구    상계1동  127.086985  ...
#
#    b_hour  b_minute       s_ymd s_day  s_dow  s_hour  s_minute  배차-예정  승차-배차  \
# 0       0        18  2018-01-23    23      1       0        34     14     16
# 1       0        50  2018-01-23    23      1       1        19     33     29
#
#   승차-예정
# 0    30
# 1    62
#
# [2 rows x 38 columns]

# %%
y1 = df1.loc[dinex1]['예정시간'].values
b1 = df1.loc[dinex1]['배차시간'].values
s1 = df1.loc[dinex1]['승차시간'].values

# %%
df1.loc[dinex1, '예정시간'] = b1
df1.loc[dinex1, '배차시간'] = s1
df1.loc[dinex1, '승차시간'] = y1

# %%
df1['y_year'] = df1['예정시간'].dt.year
df1['y_month'] = df1['예정시간'].dt.month
df1['y_ym'] = df1['예정시간'].astype(str).str[:7]
df1['y_ymd'] = df1['예정시간'].astype(str).str[:10]
df1['y_day'] = df1['예정시간'].dt.day
df1['y_dow'] = df1['예정시간'].dt.dayofweek #요일
df1['y_hour'] = df1['예정시간'].dt.hour
df1['y_minute'] = df1['예정시간'].dt.minute
df1['b_ymd'] = df1['배차시간'].astype(str).str[:10]
df1['b_day'] = df1['배차시간'].dt.day
df1['b_dow'] = df1['배차시간'].dt.dayofweek #요일
df1['b_hour'] = df1['배차시간'].dt.hour
df1['b_minute'] = df1['배차시간'].dt.minute
df1['s_ymd'] = df1['승차시간'].astype(str).str[:10]
df1['s_day'] = df1['승차시간'].dt.day
df1['s_dow'] = df1['승차시간'].dt.dayofweek #요일
df1['s_hour'] = df1['승차시간'].dt.hour
df1['s_minute'] = df1['승차시간'].dt.minute

# %%
df1['배차-예정'] = (df1['b_hour']*60 + df1['b_minute']) - (df1['y_hour']*60 + df1['y_minute'])
df1['승차-배차'] = (df1['s_hour']*60 + df1['s_minute']) - (df1['b_hour']*60 + df1['b_minute'])
df1['승차-예정'] = (df1['s_hour']*60 + df1['s_minute']) - (df1['y_hour']*60 + df1['y_minute'])

# %%
df1[df1['승차-배차'] < 0].head(3)
# Out:
#     Unnamed: 0 cartype                예정시간                배차시간  \
# 2            2    중형승합 2018-01-23 00:17:06 2018-01-23 00:30:00
# 30          30    중형승합 2018-01-23 04:32:36 2018-01-23 05:00:00
# 34          34    중형승합 2018-01-23 04:38:58 2018-01-23 05:00:00
#
#                   승차시간 startpos1 startpos2 endpos1 endpos2   start_lat  ...  \
# 2  2018-01-23 00:17:39       성북구     정릉제3동     강북구   수유제3동  127.004186  ...
# 30 2018-01-23 04:56:19       성북구       종암동     종로구   청운효자동  127.035157  ...
# 34 2018-01-23 04:55:02       중랑구     면목제5동    동대문구   휘경제2동  127.079511  ...
#
#     b_hour  b_minute       s_ymd s_day  s_dow  s_hour  s_minute  배차-예정  승차-배차  \
# 2        0        30  2018-01-23    23      1       0        17     13    -13
# 30       5         0  2018-01-23    23      1       4        56     28     -4
# 34       5         0  2018-01-23    23      1       4        55     22     -5
#
#    승차-예정
# 2      0
# 30    24
# 34    17
#
# [3 rows x 38 columns]

# %%
con2 = df1['승차-배차'] < 0

# %%
df1[con2].head(3)
# Out:
#     Unnamed: 0 cartype                예정시간                배차시간  \
# 2            2    중형승합 2018-01-23 00:17:06 2018-01-23 00:30:00
# 30          30    중형승합 2018-01-23 04:32:36 2018-01-23 05:00:00
# 34          34    중형승합 2018-01-23 04:38:58 2018-01-23 05:00:00
#
#                   승차시간 startpos1 startpos2 endpos1 endpos2   start_lat  ...  \
# 2  2018-01-23 00:17:39       성북구     정릉제3동     강북구   수유제3동  127.004186  ...
# 30 2018-01-23 04:56:19       성북구       종암동     종로구   청운효자동  127.035157  ...
# 34 2018-01-23 04:55:02       중랑구     면목제5동    동대문구   휘경제2동  127.079511  ...
#
#     b_hour  b_minute       s_ymd s_day  s_dow  s_hour  s_minute  배차-예정  승차-배차  \
# 2        0        30  2018-01-23    23      1       0        17     13    -13
# 30       5         0  2018-01-23    23      1       4        56     28     -4
# 34       5         0  2018-01-23    23      1       4        55     22     -5
#
#    승차-예정
# 2      0
# 30    24
# 34    17
#
# [3 rows x 38 columns]

# %%
dinx2 = df1[con2].index

# %%
y2 = df1.loc[dinx2]['예정시간'].values
b2 = df1.loc[dinx2]['배차시간'].values
s2 = df1.loc[dinx2]['승차시간'].values
df1.loc[dinx2, '배차시간'] = s2
df1.loc[dinx2, '승차시간'] = b2

# %%
df1[con2]
df1['y_year'] = df1['예정시간'].dt.year
df1['y_month'] = df1['예정시간'].dt.month
df1['y_ym'] = df1['예정시간'].astype(str).str[:7]
df1['y_ymd'] = df1['예정시간'].astype(str).str[:10]
df1['y_day'] = df1['예정시간'].dt.day
df1['y_dow'] = df1['예정시간'].dt.dayofweek #요일
df1['y_hour'] = df1['예정시간'].dt.hour
df1['y_minute'] = df1['예정시간'].dt.minute
df1['b_ymd'] = df1['배차시간'].astype(str).str[:10]
df1['b_day'] = df1['배차시간'].dt.day
df1['b_dow'] = df1['배차시간'].dt.dayofweek #요일
df1['b_hour'] = df1['배차시간'].dt.hour
df1['b_minute'] = df1['배차시간'].dt.minute
df1['s_ymd'] = df1['승차시간'].astype(str).str[:10]
df1['s_day'] = df1['승차시간'].dt.day
df1['s_dow'] = df1['승차시간'].dt.dayofweek #요일
df1['s_hour'] = df1['승차시간'].dt.hour
df1['s_minute'] = df1['승차시간'].dt.minute
df['배차-예정'] = (df['b_hour']*60 + df['b_minute']) - (df['y_hour']*60 + df['y_minute'])
df['승차-배차'] = (df['s_hour']*60 + df['s_minute']) - (df['b_hour']*60 + df['b_minute'])
df['승차-예정'] = (df['s_hour']*60 + df['s_minute']) - (df['y_hour']*60 + df['y_minute'])

# %%
con3 = df1['배차-예정']<0

# %%
df1[con3].head(2)
# Out:
#     Unnamed: 0 cartype                예정시간                배차시간  \
# 25          25    중형승합 2018-01-23 04:30:00 2018-01-23 04:00:59
# 27          27    중형승합 2018-01-23 04:40:00 2018-01-23 04:02:59
#
#                   승차시간 startpos1 startpos2 endpos1 endpos2   start_lat  ...  \
# 25 2018-01-23 04:47:02       구로구     오류제1동    영등포구   대림제3동  126.845201  ...
# 27 2018-01-23 04:43:09       종로구       부암동     종로구   창신제1동  126.964100  ...
#
#     b_hour  b_minute       s_ymd s_day  s_dow  s_hour  s_minute  배차-예정  승차-배차  \
# 25       4         0  2018-01-23    23      1       4        47    -30     47
# 27       4         2  2018-01-23    23      1       4        43    -38     41
#
#    승차-예정
# 25    17
# 27     3
#
# [2 rows x 38 columns]

# %%
inx3 = df1[con3].index

# %%
y3= df1[con3]['예정시간'].values
b3= df1[con3]['배차시간'].values

# %%
df1.loc[inx3,'예정시간'] = b3
df1.loc[inx3,'배차시간'] = y3

# %%
df1['y_year'] = df1['예정시간'].dt.year
df1['y_month'] = df1['예정시간'].dt.month
df1['y_ym'] = df1['예정시간'].astype(str).str[:7]
df1['y_ymd'] = df1['예정시간'].astype(str).str[:10]
df1['y_day'] = df1['예정시간'].dt.day
df1['y_dow'] = df1['예정시간'].dt.dayofweek #요일
df1['y_hour'] = df1['예정시간'].dt.hour
df1['y_minute'] = df1['예정시간'].dt.minute
df1['b_ymd'] = df1['배차시간'].astype(str).str[:10]
df1['b_day'] = df1['배차시간'].dt.day
df1['b_dow'] = df1['배차시간'].dt.dayofweek #요일
df1['b_hour'] = df1['배차시간'].dt.hour
df1['b_minute'] = df1['배차시간'].dt.minute
df1['s_ymd'] = df1['승차시간'].astype(str).str[:10]
df1['s_day'] = df1['승차시간'].dt.day
df1['s_dow'] = df1['승차시간'].dt.dayofweek #요일
df1['s_hour'] = df1['승차시간'].dt.hour
df1['s_minute'] = df1['승차시간'].dt.minute
df['배차-예정'] = (df['b_hour']*60 + df['b_minute']) - (df['y_hour']*60 + df['y_minute'])
df['승차-배차'] = (df['s_hour']*60 + df['s_minute']) - (df['b_hour']*60 + df['b_minute'])
df['승차-예정'] = (df['s_hour']*60 + df['s_minute']) - (df['y_hour']*60 + df['y_minute'])

# %%
df1.head(1)
# Out:
#    Unnamed: 0 cartype                예정시간                배차시간  \
# 0           0    중형승합 2018-01-23 00:04:00 2018-01-23 00:18:42
#
#                  승차시간 startpos1 startpos2 endpos1 endpos2   start_lat  ...  \
# 0 2018-01-23 00:34:08       성북구     장위제1동    동대문구     회기동  127.043713  ...
#
#    b_hour  b_minute       s_ymd s_day  s_dow  s_hour  s_minute  배차-예정  승차-배차  \
# 0       0        18  2018-01-23    23      1       0        34     14     16
#
#   승차-예정
# 0    30
#
# [1 rows x 38 columns]

# %%
df1 = df1.drop('Unnamed: 0', axis=1)

# %%
df1.to_csv('master_final_0707_checkplz.csv', index = False, encoding ='utf-8' )

# %% [markdown]
# # 여기부터 규동 작업

# %%
import pandas as pd
from datetime import datetime
df = pd.read_csv('master_final_0707_checkplz.csv')
df
# Out:
#        cartype                 예정시간                 배차시간                 승차시간  \
# 0         중형승합  2018-01-23 00:04:00  2018-01-23 00:18:42  2018-01-23 00:34:08
# 1         중형승합  2018-01-23 00:17:00  2018-01-23 00:50:37  2018-01-23 01:19:22
# 2         중형승합  2018-01-23 00:17:06  2018-01-23 00:17:39  2018-01-23 00:30:00
# 3         중형승합  2018-01-23 00:47:00  2018-01-23 00:51:19  2018-01-23 01:09:33
# 4         중형승합  2018-01-23 01:08:00  2018-01-23 01:44:17  2018-01-23 02:06:53
# ...        ...                  ...                  ...                  ...
# 407548    대형승용  2022-06-24 07:00:00  2022-06-24 07:12:38  2022-06-24 07:55:24
# 407549    중형승합  2022-06-24 07:00:00  2022-06-24 07:09:10  2022-06-24 07:25:35
# 407550    중형승합  2022-06-24 07:00:00  2022-06-24 07:04:27  2022-06-24 07:25:35
# 407551    중형승합  2022-06-24 06:55:01  2022-06-24 07:00:00  2022-06-24 08:06:22
# 407552    중형승합  2022-06-24 07:00:00  2022-06-24 07:05:08  2022-06-24 08:31:07
#
# ...

# %%
aa = df[['예정시간', '배차시간', '승차시간','distance', 'duration', 'taxiFare', '배차-예정', '승차-배차', '승차-예정']]
aa
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 0       2018-01-23 00:04:00  2018-01-23 00:18:42  2018-01-23 00:34:08
# 1       2018-01-23 00:17:00  2018-01-23 00:50:37  2018-01-23 01:19:22
# 2       2018-01-23 00:17:06  2018-01-23 00:17:39  2018-01-23 00:30:00
# 3       2018-01-23 00:47:00  2018-01-23 00:51:19  2018-01-23 01:09:33
# 4       2018-01-23 01:08:00  2018-01-23 01:44:17  2018-01-23 02:06:53
# ...                     ...                  ...                  ...
# 407548  2022-06-24 07:00:00  2022-06-24 07:12:38  2022-06-24 07:55:24
# 407549  2022-06-24 07:00:00  2022-06-24 07:09:10  2022-06-24 07:25:35
# 407550  2022-06-24 07:00:00  2022-06-24 07:04:27  2022-06-24 07:25:35
# 407551  2022-06-24 06:55:01  2022-06-24 07:00:00  2022-06-24 08:06:22
# 407552  2022-06-24 07:00:00  2022-06-24 07:05:08  2022-06-24 08:31:07
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정
# 0           4289   648.464      5600     14     16     30
# ...

# %%
for i in range(len(aa)):
    aa['예정시간'][i] = datetime.strptime(aa['예정시간'][i], '%Y-%m-%d %H:%M:%S')
    aa['배차시간'][i] = datetime.strptime(aa['배차시간'][i], '%Y-%m-%d %H:%M:%S')
    aa['승차시간'][i] = datetime.strptime(aa['승차시간'][i], '%Y-%m-%d %H:%M:%S')
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1734117255.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['예정시간'][i] = datetime.strptime(aa['예정시간'][i], '%Y-%m-%d %H:%M:%S')
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1734117255.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['배차시간'][i] = datetime.strptime(aa['배차시간'][i], '%Y-%m-%d %H:%M:%S')
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1734117255.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
y_b_time = []
b_s_time = []
y_s_time = []
for i in range(len(aa)):
    y_b_time.append((aa['배차시간'][i] - aa['예정시간'][i]).seconds)
    b_s_time.append((aa['승차시간'][i] - aa['배차시간'][i]).seconds)
    y_s_time.append((aa['승차시간'][i] - aa['예정시간'][i]).seconds)

# %%
aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\637596476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\637596476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\637596476.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
y_b_seconds = []
b_s_seconds = []
y_s_seconds = []
for i in range(len(aa)):
    y_b_seconds.append(aa['y_b_time'][i].seconds)
    b_s_seconds.append(aa['b_s_time'][i].seconds)
    y_s_seconds.append(aa['y_s_time'][i].seconds)
aa['y_b_seconds'] = y_b_seconds
aa['b_s_seconds'] = b_s_seconds
aa['y_s_seconds'] = y_s_seconds
aa.head(1)
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3160341020.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_seconds'] = y_b_seconds
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3160341020.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_seconds'] = b_s_seconds
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3160341020.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
aa.head(1)
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3647909810.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_days'] = y_b_days
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3647909810.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_days'] = b_s_days
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3647909810.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 0       2018-01-23 00:04:00  2018-01-23 00:18:42  2018-01-23 00:34:08
# 1       2018-01-23 00:17:00  2018-01-23 00:50:37  2018-01-23 01:19:22
# 2       2018-01-23 00:17:06  2018-01-23 00:17:39  2018-01-23 00:30:00
# 3       2018-01-23 00:47:00  2018-01-23 00:51:19  2018-01-23 01:09:33
# 4       2018-01-23 01:08:00  2018-01-23 01:44:17  2018-01-23 02:06:53
# ...                     ...                  ...                  ...
# 407548  2022-06-24 07:00:00  2022-06-24 07:12:38  2022-06-24 07:55:24
# 407549  2022-06-24 07:00:00  2022-06-24 07:09:10  2022-06-24 07:25:35
# 407550  2022-06-24 07:00:00  2022-06-24 07:04:27  2022-06-24 07:25:35
# 407551  2022-06-24 06:55:01  2022-06-24 07:00:00  2022-06-24 08:06:22
# 407552  2022-06-24 07:00:00  2022-06-24 07:05:08  2022-06-24 08:31:07
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정        y_b_time  \
# ...

# %%
aa[aa['y_b_days'] != 0]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 32846   2018-05-22 01:22:39  2018-05-08 07:00:00  2018-05-08 08:34:46
# 32847   2018-05-22 00:53:31  2018-05-08 06:49:31  2018-05-08 07:00:00
# 33095   2018-05-23 00:32:39  2018-05-22 08:55:00  2018-05-22 09:08:17
# 33096   2018-05-23 00:25:44  2018-05-22 08:57:00  2018-05-22 09:06:13
# 33344   2018-05-06 00:08:58  2018-05-23 07:00:00  2018-05-23 07:09:57
# ...                     ...                  ...                  ...
# 407339  2022-06-24 05:48:38  2022-06-18 08:08:00  2022-06-18 08:08:27
# 407340  2022-06-24 05:10:33  2022-06-18 08:08:40  2022-06-18 08:10:01
# 407341  2022-06-24 06:02:21  2022-06-18 08:08:42  2022-06-18 08:10:00
# 407342  2022-06-24 05:37:15  2022-06-18 08:08:58  2022-06-18 08:12:20
# 407343  2022-06-24 05:29:22  2022-06-18 08:09:00  2022-06-18 08:17:13
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정           y_b_time  \
# ...

# %%
aa[aa['y_b_days'] < 0]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 32846   2018-05-22 01:22:39  2018-05-08 07:00:00  2018-05-08 08:34:46
# 32847   2018-05-22 00:53:31  2018-05-08 06:49:31  2018-05-08 07:00:00
# 33095   2018-05-23 00:32:39  2018-05-22 08:55:00  2018-05-22 09:08:17
# 33096   2018-05-23 00:25:44  2018-05-22 08:57:00  2018-05-22 09:06:13
# 33592   2018-05-12 00:39:13  2018-05-06 08:27:00  2018-05-06 08:58:08
# ...                     ...                  ...                  ...
# 407339  2022-06-24 05:48:38  2022-06-18 08:08:00  2022-06-18 08:08:27
# 407340  2022-06-24 05:10:33  2022-06-18 08:08:40  2022-06-18 08:10:01
# 407341  2022-06-24 06:02:21  2022-06-18 08:08:42  2022-06-18 08:10:00
# 407342  2022-06-24 05:37:15  2022-06-18 08:08:58  2022-06-18 08:12:20
# 407343  2022-06-24 05:29:22  2022-06-18 08:09:00  2022-06-18 08:17:13
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정           y_b_time  \
# ...

# %%
t1 = aa[aa['y_b_days'] < 0]['예정시간']
t2 = aa[aa['y_b_days'] < 0]['배차시간']

for i in t1.index:
    aa.loc[i, '예정시간'] = dt.datetime(t2[i].year, t2[i].month, t2[i].day, t1[i].hour, t1[i].minute, t1[i].second)
aa
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 0       2018-01-23 00:04:00  2018-01-23 00:18:42  2018-01-23 00:34:08
# 1       2018-01-23 00:17:00  2018-01-23 00:50:37  2018-01-23 01:19:22
# 2       2018-01-23 00:17:06  2018-01-23 00:17:39  2018-01-23 00:30:00
# 3       2018-01-23 00:47:00  2018-01-23 00:51:19  2018-01-23 01:09:33
# 4       2018-01-23 01:08:00  2018-01-23 01:44:17  2018-01-23 02:06:53
# ...                     ...                  ...                  ...
# 407548  2022-06-24 07:00:00  2022-06-24 07:12:38  2022-06-24 07:55:24
# 407549  2022-06-24 07:00:00  2022-06-24 07:09:10  2022-06-24 07:25:35
# 407550  2022-06-24 07:00:00  2022-06-24 07:04:27  2022-06-24 07:25:35
# 407551  2022-06-24 06:55:01  2022-06-24 07:00:00  2022-06-24 08:06:22
# 407552  2022-06-24 07:00:00  2022-06-24 07:05:08  2022-06-24 08:31:07
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정        y_b_time  \
# ...

# %%
aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\637596476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\637596476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\637596476.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
aa[aa['y_b_days'] < 0]
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3701516781.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_days'] = y_b_days
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3701516781.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_days'] = b_s_days
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3701516781.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
t1 = aa[aa['y_b_days'] < 0]['예정시간']

for i in t1.index:
    a = aa['예정시간'][i]
    b = aa['배차시간'][i]
    aa.loc[i, '예정시간'] = b
    aa.loc[i, '배차시간'] = a

# %%
aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
aa[aa['y_b_days'] < 0]
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3938804469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3938804469.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3938804469.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa[(aa['b_s_days'] < 0)]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 28993   2018-04-14 07:16:00  2018-04-14 07:16:37  2018-04-14 07:16:00
# 33298   2018-05-23 07:00:00  2018-05-23 07:24:28  2018-05-23 07:24:21
# 33312   2018-05-23 07:00:00  2018-05-23 07:45:32  2018-05-23 07:45:20
# 34017   2018-05-13 08:00:00  2018-05-13 08:08:57  2018-05-13 08:08:35
# 34057   2018-05-13 08:09:00  2018-05-13 08:53:52  2018-05-13 08:53:45
# ...                     ...                  ...                  ...
# 404601  2022-06-13 07:00:00  2022-06-13 07:05:07  2022-06-12 07:23:53
# 404602  2022-06-13 06:35:02  2022-06-13 07:00:00  2022-06-12 07:17:44
# 404603  2022-06-13 07:00:00  2022-06-13 07:10:17  2022-06-12 07:24:47
# 404604  2022-06-13 07:00:00  2022-06-13 07:10:12  2022-06-12 07:14:21
# 405720  2022-06-08 07:00:00  2022-06-08 07:09:45  2022-06-08 07:09:13
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정        y_b_time  \
# ...

# %%
s1 = aa[aa['b_s_days'] < 0]['예정시간']

for i in s1.index:
    a = aa['예정시간'][i]
    b = aa['배차시간'][i]
    c = aa['승차시간'][i]
    aa.loc[i, '예정시간'] = c
    aa.loc[i, '배차시간'] = a
    aa.loc[i, '승차시간'] = b

# %%
aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
aa[aa['b_s_days'] < 0]
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1892250832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1892250832.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1892250832.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa[(aa['y_b_days'] < 0)]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 33298   2018-05-23 07:24:21  2018-05-23 07:00:00  2018-05-23 07:24:28
# 33312   2018-05-23 07:45:20  2018-05-23 07:00:00  2018-05-23 07:45:32
# 34017   2018-05-13 08:08:35  2018-05-13 08:00:00  2018-05-13 08:08:57
# 34057   2018-05-13 08:53:45  2018-05-13 08:09:00  2018-05-13 08:53:52
# 34716   2018-05-05 07:45:12  2018-05-05 07:21:00  2018-05-05 07:45:16
# ...                     ...                  ...                  ...
# 402158  2022-06-03 07:17:24  2022-06-03 07:00:00  2022-06-03 07:17:29
# 402525  2022-06-15 07:08:39  2022-06-15 07:00:00  2022-06-15 07:08:43
# 403294  2022-06-10 07:05:34  2022-06-10 07:00:00  2022-06-10 07:05:38
# 403774  2022-06-05 08:59:13  2022-06-05 08:24:16  2022-06-05 08:59:51
# 405720  2022-06-08 07:09:13  2022-06-08 07:00:00  2022-06-08 07:09:45
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정          y_b_time  \
# ...

# %%
t1 = aa[aa['y_b_days'] < 0]['예정시간']

for i in t1.index:
    a = aa['예정시간'][i]
    b = aa['배차시간'][i]
    aa.loc[i, '예정시간'] = b
    aa.loc[i, '배차시간'] = a

aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
aa[aa['y_b_days'] < 0]
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1672592134.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1672592134.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1672592134.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa[aa['y_b_days'] > 1]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 33344   2018-05-06 00:08:58  2018-05-23 07:00:00  2018-05-23 07:09:57
# 33345   2018-05-06 00:56:55  2018-05-23 07:00:00  2018-05-23 07:04:20
# 34090   2018-05-07 01:33:05  2018-05-13 08:18:00  2018-05-13 08:49:02
# 34091   2018-05-07 01:02:29  2018-05-13 08:18:00  2018-05-13 08:39:27
# 34092   2018-05-07 00:58:07  2018-05-13 08:18:00  2018-05-13 08:39:30
# ...                     ...                  ...                  ...
# 406841  2022-06-19 05:38:25  2022-06-25 08:18:25  2022-06-25 08:28:01
# 406842  2022-06-19 05:43:37  2022-06-25 08:18:46  2022-06-25 08:26:22
# 406843  2022-06-19 06:26:20  2022-06-25 08:19:33  2022-06-25 08:26:21
# 406844  2022-06-19 07:35:19  2022-06-25 08:19:49  2022-06-25 08:29:39
# 406845  2022-06-19 07:17:47  2022-06-25 08:20:00  2022-06-25 08:33:47
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정         y_b_time  \
# ...

# %%
t1 = aa[aa['y_b_days'] > 0]['예정시간']
t2 = aa[aa['y_b_days'] > 0]['배차시간']

for i in t1.index:
    aa.loc[i, '예정시간'] = dt.datetime(t2[i].year, t2[i].month, t2[i].day, t1[i].hour, t1[i].minute, t1[i].second)

# %%
aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
aa[aa['y_b_days'] > 0]
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\4056415368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\4056415368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\4056415368.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa[aa['y_b_days'] > 0]
# Out:
# Empty DataFrame
# Columns: [예정시간, 배차시간, 승차시간, distance, duration, taxiFare, 배차-예정, 승차-배차, 승차-예정, y_b_time, b_s_time, y_s_time, y_b_seconds, b_s_seconds, y_s_seconds, y_b_days, b_s_days, y_s_days]
# Index: []

# %%
aa[aa['y_b_days'] < 0]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 64215   2018-09-13 23:59:32  2018-09-13 07:00:00  2018-09-13 07:10:21
# 66457   2018-09-25 23:58:00  2018-09-25 10:00:00  2018-09-25 10:04:58
# 68448   2018-10-03 23:57:42  2018-10-03 09:02:00  2018-10-03 09:02:14
# 70689   2018-10-11 23:44:49  2018-10-11 07:00:00  2018-10-11 07:46:24
# 75422   2018-10-27 23:49:00  2018-10-27 08:00:00  2018-10-27 08:00:29
# 112770  2019-03-15 07:24:57  2019-03-15 07:00:00  2019-03-15 07:17:33
# 112773  2019-03-15 07:28:55  2019-03-15 07:00:00  2019-03-15 07:09:19
# 162075  2019-10-15 07:20:27  2019-10-15 07:00:00  2019-10-15 07:09:17
# 162076  2019-10-15 07:30:17  2019-10-15 07:00:00  2019-10-15 07:08:38
# 162077  2019-10-15 07:19:56  2019-10-15 07:00:00  2019-10-15 07:05:20
# 162078  2019-10-15 07:33:31  2019-10-15 06:48:39  2019-10-15 07:00:00
# 250201  2020-10-21 23:35:37  2020-10-21 07:18:00  2020-10-21 07:24:32
# ...

# %%
aa.loc[64215,"예정시간"].second
# Out:
# 32

# %%
aa.loc[64215,"예정시간"].hour * 3600 + aa.loc[64215,"예정시간"].minute * 60 + aa.loc[64215,"예정시간"].second
# Out:
# 86372

# %%
aa.loc[0,"예정시간"].hour * 3600 + aa.loc[0,"예정시간"].minute * 60 + aa.loc[0,"예정시간"].second
# Out:
# 240

# %%
aa['예정시간'][64215].seconds
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [195], in <cell line: 1>()
# ----> 1 aa['예정시간'][64215].seconds()
#
# AttributeError: 'datetime.datetime' object has no attribute 'seconds'

# %%
nightindex = []

# %%
for i in aa.index:
	t = aa.loc[i,"예정시간"].hour * 3600 + aa.loc[i,"예정시간"].minute * 60 + aa.loc[i,"예정시간"].second
	if t >= 79200:
		ival = i
		nightindex.append(ival)

# %%
nihi = aa.loc[nightindex][aa.loc[nightindex]['y_b_days'] == -1].index

# %%
aa.loc[nihi, '예정시간'] = aa.loc[nightindex][aa.loc[nightindex]['y_b_days'] == -1]['예정시간']-dt.timedelta(days=1)

# %%
aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days

aa.loc[nightindex][aa.loc[nightindex]['y_b_days'] == -1]
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3645121177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3645121177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3645121177.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa[aa['y_b_days'] < 0]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 112770  2019-03-15 07:24:57  2019-03-15 07:00:00  2019-03-15 07:17:33
# 112773  2019-03-15 07:28:55  2019-03-15 07:00:00  2019-03-15 07:09:19
# 162075  2019-10-15 07:20:27  2019-10-15 07:00:00  2019-10-15 07:09:17
# 162076  2019-10-15 07:30:17  2019-10-15 07:00:00  2019-10-15 07:08:38
# 162077  2019-10-15 07:19:56  2019-10-15 07:00:00  2019-10-15 07:05:20
# 162078  2019-10-15 07:33:31  2019-10-15 06:48:39  2019-10-15 07:00:00
# 267156  2020-12-31 08:04:43  2020-12-31 07:58:58  2020-12-31 08:00:00
# 283582  2021-02-16 07:57:17  2021-02-16 07:41:00  2021-02-16 07:43:12
# 283584  2021-02-16 07:48:32  2021-02-16 07:41:43  2021-02-16 07:42:57
# 290311  2021-03-29 07:32:06  2021-03-29 07:23:33  2021-03-29 07:29:38
# 301511  2021-04-30 08:19:06  2021-04-30 07:32:00  2021-04-30 07:36:49
# 327657  2021-08-24 07:23:18  2021-08-24 07:08:15  2021-08-24 07:20:00
# ...

# %%
t1 = aa[aa['y_b_days'] < 0]['예정시간']

for i in t1.index:
    a = aa['예정시간'][i]
    b = aa['배차시간'][i]
    c = aa['승차시간'][i]
    aa.loc[i, '예정시간'] = b
    aa.loc[i, '배차시간'] = c
    aa.loc[i, '승차시간'] = a

aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1360698015.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1360698015.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\1360698015.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa[aa['b_s_days'] < 0]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 346335  2021-10-07 07:10:38  2021-10-07 07:17:24  2021-10-07 07:17:14
# 366996  2022-01-14 07:24:04  2022-01-14 07:25:23  2022-01-14 07:25:14
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정        y_b_time  \
# 346335     16320  1569.123     18050      7      0      7 0 days 00:06:46
# 366996      3603   576.674      5200      1      0      1 0 days 00:01:19
#
#                 b_s_time        y_s_time  y_b_seconds  b_s_seconds  \
# 346335 -1 days +23:59:50 0 days 00:06:36          406        86390
# 366996 -1 days +23:59:51 0 days 00:01:10           79        86391
#
#         y_s_seconds  y_b_days  b_s_days  y_s_days
# 346335          396         0        -1         0
# 366996           70         0        -1         0

# %%
t1 = aa[aa['b_s_days'] < 0]['배차시간']

for i in t1.index:
    b = aa['배차시간'][i]
    c = aa['승차시간'][i]
    aa.loc[i, '배차시간'] = c
    aa.loc[i, '승차시간'] = b

aa['y_b_time'] = aa['배차시간']-aa['예정시간']
aa['b_s_time'] = aa['승차시간']-aa['배차시간']
aa['y_s_time'] = aa['승차시간']-aa['예정시간']
y_b_days = []
b_s_days = []
y_s_days = []
for i in range(len(aa)):
    y_b_days.append(aa['y_b_time'][i].days)
    b_s_days.append(aa['b_s_time'][i].days)
    y_s_days.append(aa['y_s_time'][i].days)
aa['y_b_days'] = y_b_days
aa['b_s_days'] = b_s_days
aa['y_s_days'] = y_s_days
# Out:
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3010138729.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['y_b_time'] = aa['배차시간']-aa['예정시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3010138729.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['b_s_time'] = aa['승차시간']-aa['배차시간']
# C:\Users\rbehd\AppData\Local\Temp\ipykernel_19168\3010138729.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aa[aa['b_s_days'] != 0]
# Out:
#                        예정시간                 배차시간                 승차시간  \
# 78659   2018-11-07 07:00:00  2018-11-07 07:52:22  2018-11-12 23:37:37
# 79161   2018-11-05 07:00:00  2018-11-05 07:33:37  2018-11-10 23:45:14
# 187472  2020-01-22 07:06:00  2020-01-22 08:20:13  2020-01-26 07:20:12
# 187473  2020-01-22 07:06:00  2020-01-22 08:05:13  2020-01-26 07:52:15
# 187474  2020-01-22 07:07:00  2020-01-22 08:09:05  2020-01-26 07:25:40
# ...                     ...                  ...                  ...
# 392403  2022-04-24 07:04:00  2022-04-24 07:18:18  2022-04-26 07:42:48
# 393398  2022-04-19 07:07:48  2022-04-19 07:25:57  2022-04-25 07:20:44
# 399125  2022-05-08 07:01:00  2022-05-08 07:22:02  2022-05-20 08:06:29
# 399126  2022-05-08 07:01:09  2022-05-08 07:25:16  2022-05-20 08:16:34
# 404600  2022-06-12 07:00:00  2022-06-12 07:14:42  2022-06-13 08:00:17
#
#         distance  duration  taxiFare  배차-예정  승차-배차  승차-예정        y_b_time  \
# ...

# %%
aa[aa['b_s_days'] != 0].to_csv('전처리해주세요.csv', encoding='utf-8')

# %%
aa.to_csv('전처리한거여기에붙이세요.csv', encoding='utf-8')

# %% [markdown]
# # redo

# %%
import pandas as pd

# %%
fs = pd.read_csv('전처리해주세요.csv', index_col= 0)
fs.head()
# Out:
#                        예정시간                배차시간                승차시간  distance  \
# 78659   2018-11-06 23:37:37  2018-11-07 7:00:00  2018-11-07 7:52:22     15450
# 79161   2018-11-04 23:45:14  2018-11-05 7:00:00  2018-11-05 7:33:37      8467
# 187472   2020-01-22 7:06:00  2020-01-22 7:20:12  2020-01-22 8:20:13      2178
# 187473   2020-01-22 7:06:00  2020-01-22 7:52:15  2020-01-22 8:05:13     31075
# 187474   2020-01-22 7:07:00  2020-01-22 7:25:40  2020-01-22 8:09:05      2326
#
#         duration  taxiFare  배차-예정  승차-배차  승차-예정         y_b_time  \
# 78659   2213.620     15500     52    945    997  0 days 00:52:22
# 79161   1460.117      9600     33    972   1005  0 days 00:33:37
# 187472   422.390      3900     14     60     74  0 days 01:14:13
# 187473  3316.361     30170     46     13     59  0 days 00:59:13
# 187474   493.224      4100     18     44     62  0 days 01:02:05
#
#                b_s_time         y_s_time  y_b_seconds  b_s_seconds  \
# ...

# %%
fb = pd.read_csv('전처리한거여기에붙이세요.csv', index_col= 0)

# %%
for i in fs.index:
    fb.loc[i, '예정시간'] = fs['예정시간'][i]
    fb.loc[i, '승차시간'] = fs['승차시간'][i]
    fb.loc[i, '배차시간'] = fs['배차시간'][i]

# %%
fb['예정시간'] = pd.to_datetime(fb['예정시간'])
fb['배차시간'] = pd.to_datetime(fb['배차시간'])
fb['승차시간'] = pd.to_datetime(fb['승차시간'])

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407553 entries, 0 to 407552
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   예정시간         407553 non-null  datetime64[ns]
#  1   배차시간         407553 non-null  datetime64[ns]
#  2   승차시간         407553 non-null  datetime64[ns]
#  3   distance     407553 non-null  int64
#  4   duration     407553 non-null  float64
#  5   taxiFare     407553 non-null  int64
#  6   배차-예정        407553 non-null  int64
#  7   승차-배차        407553 non-null  int64
#  8   승차-예정        407553 non-null  int64
#  9   y_b_time     407553 non-null  object
#  10  b_s_time     407553 non-null  object
#  11  y_s_time     407553 non-null  object
#  12  y_b_seconds  407553 non-null  int64
#  13  b_s_seconds  407553 non-null  int64
#  14  y_s_seconds  407553 non-null  int64
#  15  y_b_days     407553 non-null  int64
#  16  b_s_days     407553 non-null  int64
# ...

# %%
fb['y_b_time'] = fb['배차시간']-fb['예정시간']
fb['b_s_time'] = fb['승차시간']-fb['배차시간']
fb['y_s_time'] = fb['승차시간']-fb['예정시간']

# %%
import datetime as dt

# %%
fb['y_b_days'] = fb['y_b_time'].dt.seconds
fb['b_s_days'] = fb['b_s_time'].dt.seconds
fb['y_s_days'] = fb['y_s_time'].dt.seconds
fb['y_b_days'] = fb['y_b_time'].dt.days
fb['b_s_days'] = fb['b_s_time'].dt.days
fb['y_s_days'] = fb['y_s_time'].dt.days

# %%
df
# Out:
#        cartype startpos1 startpos2 endpos1 endpos2   start_lat  start_lng  \
# 0         중형승합       성북구     장위제1동    동대문구     회기동  127.043713  37.614125
# 1         중형승합       중랑구     면목제7동     노원구    상계1동  127.086985  37.578995
# 2         중형승합       성북구     정릉제3동     강북구   수유제3동  127.004186  37.608958
# 3         중형승합       구로구     고척제2동     관악구     은천동  126.858712  37.506706
# 4         중형승합      동대문구       회기동     성북구   장위제2동  127.055313  37.590808
# ...        ...       ...       ...     ...     ...         ...        ...
# 407548    대형승용       성북구     돈암제2동     강남구    대치4동  127.010566  37.598039
# 407549    중형승합       은평구       구산동     은평구     구산동  126.910389  37.611745
# 407550    중형승합       노원구      상계8동    영등포구    영등포동  127.051587  37.666785
# 407551    중형승합       성북구     길음제1동     강북구    번제1동  127.019392  37.610486
# 407552    중형승합       강동구     천호제2동     강동구   명일제1동  127.125435  37.543526
#
#            end_lat    end_lng   direction  distance  duration  taxiFare
# ...

# %%
fb.head(2)
# Out:
#                  예정시간                배차시간                승차시간  distance  \
# 0 2018-01-23 00:04:00 2018-01-23 00:18:42 2018-01-23 00:34:08      4289
# 1 2018-01-23 00:17:00 2018-01-23 00:50:37 2018-01-23 01:19:22     14493
#
#    duration  taxiFare  배차-예정  승차-배차  승차-예정        y_b_time        b_s_time  \
# 0   648.464      5600     14     16     30 0 days 00:14:42 0 days 00:15:26
# 1  1318.675     13700     33     29     62 0 days 00:33:37 0 days 00:28:45
#
#          y_s_time  y_b_seconds  b_s_seconds  y_s_seconds  y_b_days  b_s_days  \
# 0 0 days 00:30:08          882          926         1808         0         0
# 1 0 days 01:02:22         2017         1725         3742         0         0
#
#    y_s_days
# 0         0
# 1         0

# %%
df = df[['cartype', 'startpos1', 'startpos2', 'endpos1',
       'endpos2', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'direction',
       'distance', 'duration', 'taxiFare']]

# %%
df.head(2)
# Out:
#   cartype startpos1 startpos2 endpos1 endpos2   start_lat  start_lng  \
# 0    중형승합       성북구     장위제1동    동대문구     회기동  127.043713  37.614125
# 1    중형승합       중랑구     면목제7동     노원구    상계1동  127.086985  37.578995
#
#       end_lat    end_lng  direction  distance  duration  taxiFare
# 0  127.055313  37.590808   장위제1동회기동      4289   648.464      5600
# 1  127.054978  37.679901  면목제7동상계1동     14493  1318.675     13700

# %%
fff = fb[['예정시간', '배차시간', '승차시간', 'distance', 'y_b_time',
       'b_s_time', 'y_s_time', 'y_b_seconds', 'b_s_seconds', 'y_s_seconds',
       'y_b_days', 'b_s_days', 'y_s_days']]

# %%
fff = fff.rename(columns = {'distance': 'dummy'})

# %%
fff.head(2)
# Out:
#                  예정시간                배차시간                승차시간  dummy  \
# 0 2018-01-23 00:04:00 2018-01-23 00:18:42 2018-01-23 00:34:08   4289
# 1 2018-01-23 00:17:00 2018-01-23 00:50:37 2018-01-23 01:19:22  14493
#
#          y_b_time        b_s_time        y_s_time  y_b_seconds  b_s_seconds  \
# 0 0 days 00:14:42 0 days 00:15:26 0 days 00:30:08          882          926
# 1 0 days 00:33:37 0 days 00:28:45 0 days 01:02:22         2017         1725
#
#    y_s_seconds  y_b_days  b_s_days  y_s_days
# 0         1808         0         0         0
# 1         3742         0         0         0

# %%
pd.set_option('display.max_columns', None)

# %%
finale = pd.concat([df, fff], axis=1)

# %%
finale.head(2)
# Out:
#   cartype startpos1 startpos2 endpos1 endpos2   start_lat  start_lng  \
# 0    중형승합       성북구     장위제1동    동대문구     회기동  127.043713  37.614125
# 1    중형승합       중랑구     면목제7동     노원구    상계1동  127.086985  37.578995
#
#       end_lat    end_lng  direction  distance  duration  taxiFare  \
# 0  127.055313  37.590808   장위제1동회기동      4289   648.464      5600
# 1  127.054978  37.679901  면목제7동상계1동     14493  1318.675     13700
#
#                  예정시간                배차시간                승차시간  dummy  \
# 0 2018-01-23 00:04:00 2018-01-23 00:18:42 2018-01-23 00:34:08   4289
# 1 2018-01-23 00:17:00 2018-01-23 00:50:37 2018-01-23 01:19:22  14493
#
#          y_b_time        b_s_time        y_s_time  y_b_seconds  b_s_seconds  \
# 0 0 days 00:14:42 0 days 00:15:26 0 days 00:30:08          882          926
# 1 0 days 00:33:37 0 days 00:28:45 0 days 01:02:22         2017         1725
#
#    y_s_seconds  y_b_days  b_s_days  y_s_days
# 0         1808         0         0         0
# ...

# %%
finale = finale.drop(['dummy','y_b_days', 'y_s_days', 'b_s_days'], axis=1)

# %%
finale= finale[['cartype', '예정시간', '배차시간', '승차시간','startpos1', 'startpos2', 'endpos1', 'endpos2','direction',
        'start_lat', 'start_lng', 'end_lat', 'end_lng', 
        'distance', 'duration', 'taxiFare', 'y_b_time', 'b_s_time', 'y_s_time',
       'y_b_seconds', 'b_s_seconds', 'y_s_seconds']]

# %%
finale.to_csv('master_final_220708.csv', index = False, encoding= 'utf-8')
